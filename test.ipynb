# %%
import pandas as pd
df = pd.read_csv(r'df_merged.csv')
df.head(100)
# Out:
#          code        date      open     close      high       low      volumn  \
# 0   000001.SZ  2011-02-01  3.957125  3.988121  4.001036  3.941627  15169758.0
# 1   000001.SZ  2011-02-09  3.964874  3.939045  4.016534  3.933879  16650833.0
# 2   000001.SZ  2011-02-10  3.939045  3.990704  3.995870  3.926130  13682225.0
# 3   000001.SZ  2011-02-11  3.972623  4.003619  4.026866  3.951959  22582808.0
# 4   000001.SZ  2011-02-14  4.001036  4.132768  4.156015  3.998453  41765667.0
# ..        ...         ...       ...       ...       ...       ...         ...
# 95  000001.SZ  2011-07-04  4.388483  4.533130  4.535713  4.383317  37824912.0
# 96  000001.SZ  2011-07-05  4.520215  4.494385  4.527964  4.463389  19056022.0
# 97  000001.SZ  2011-07-06  4.471138  4.453058  4.486636  4.403981  20647586.0
# 98  000001.SZ  2011-07-07  4.520215  4.465972  4.553794  4.427228  33785505.0
# 99  000001.SZ  2011-07-08  4.465972  4.525381  4.597704  4.447892  26960365.0
#
#         vwap    return      turn
# 0   3.978501  0.849118  0.488503
# 1   3.970909 -1.230570  0.536197
# 2   3.967080  1.311475  0.440600
# 3   3.982071  0.323625  0.727221
# 4   4.092527  3.225806  1.344955
# ..       ...       ...       ...
# 95  4.479617  3.662138  1.218053
# 96  4.496267 -0.854701  0.613650
# 97  4.436334 -0.919540  0.664902
# 98  4.500179  0.290023  1.087974
# 99  4.536791  1.330249  0.868188
#
# [100 rows x 10 columns]

# %%
import numpy as np
X = np.load('X_fe.npy')             # (样本数,特征数,窗口长度) 
Y = np.load('Y_fe.npy')        # (样本数,)      
dates = np.load('Y_dates.npy')      # (样本数,)
print(X.shape)
print(Y.shape)
print(dates.shape)
# Out:
# (1228074, 8, 30)
# (1228074,)
# (1228074,)
